# %%
file = open("1.txt", "r")
x = []
y = []
z = []
for i in file.readlines()[::]:
    if i[0] == "(":
        jam = i.strip('()').split(",")
        x.append(float(jam[0]))
        y.append(float(jam[1]))
        jam = i.strip('()\n').split(",")
        z.append(float(jam[2]))

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-bf52d2c870aa> in <module>
# ----> 1 count(x)
#
# NameError: name 'count' is not defined

# %%
type(file.readlines())
# Out:
# list

# %%
j = file.readlines()[::]

# %%
str(j)
# Out:
# '[]'

# %%
# for i in range(len(x)):
#     print(x[i], end=" ")

# %%
for i in range(2000):
    print(x[i], end=" ")
# Out:
# 0.24049437046051025 0.24160410463809967 0.24517114460468292 0.2476017326116562 0.2507737874984741 0.2520666718482971 0.2526950538158417 0.2523404061794281 0.25199177861213684 0.24976351857185364 0.24656617641448975 0.24408935010433197 0.24290333688259125 0.23906107246875763 0.2364744395017624 0.23538537323474884 0.23326334357261658 0.232480987906456 0.2311629205942154 0.23083814978599548 0.23071202635765076 0.23184244334697723 0.23263657093048096 0.23486849665641785 0.23624147474765778 0.2396802306175232 0.24154537916183472 0.245846688747406 0.24794985353946686 0.25326305627822876 0.2558465301990509 0.2614884078502655 0.26684752106666565 0.2693724036216736 0.27151191234588623 0.2756608724594116 0.27990272641181946 0.2815261483192444 0.28205007314682007 0.28266099095344543 0.28241944313049316 0.2817692160606384 0.2807536721229553 0.2786746919155121 0.25604018568992615 0.25201916694641113 0.2484201341867447 0.24634450674057007 0.24061349034309387 0.23774757981300354 0.23483408987522125
# ...

# %%
print(type(keep))
# Out:
# <class 'str'>

# %% [markdown]
# 1. ตัดประโยคแรกออก
# 2. ตัดทุกอย่างออกให้เหลือแต่ no. of stroke
# 3. เก็บค่าตัวแรกที่เจอไว้ในตัวแปร x
#     ตัดทุกอย่างที่เจอออก
#     detect ( กับ ) ก่อน
#     จัด for เข้าไปในลูป append ตัวแรกไปใน set x, append ตัวที่สองไปใน set y

# %% [markdown]
# ที่จะทำ
# 1. ให้ matlab อ่าน text file ได้
# 2. เก็บไปในตัวแปร x,y,z (ให้มีตัว split stroke แต่ละ stroke)
#      ก็คือเมื่อจบ 1 การตวัด หรือก่อนถึง no. of stroke อะ ก็ให้มันเผื่อคำไว้ 1 บรรทัด(eg 111,222,3333)
#       2 approachs
#      2.1 เหมือนปกติเลย
#      - Can I make cell store here like
#      - mycell = {1,2,3;'test1', [1:2], false}
#          represent test1 as x, [2] as y and [3] as z
#
#      2.2 เก็บทั้งหมดไว้ใน 1 cell
# 3. plot พวกนั้นออกมาเลย
